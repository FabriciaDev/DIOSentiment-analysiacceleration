# %% [markdown]
# <a href="https://colab.research.google.com/github/FabriciaDev/DIOSentiment-analysiacceleration/blob/main/Projeto1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Testing the Emotion Detector model**

# %% [markdown]
# Primeiro projeto da Acelereção promovida pela DIO com a instrutora Isadora Ferrão

# %% [markdown]
# ## Importando as bibliotecas

# %%
import cv2
import numpy as np
import pandas as pd
from google.colab.patches import cv2_imshow
import zipfile

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
tensorflow.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ## Conectando ao Drive e acessando os arquivos

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/MyDrive/Colab Notebooks/Implementing Artificial Intelligence for Emotion Detection/Projeto 1/files.zip"
zip_object = zipfile.ZipFile(file = path, mode = "r")
zip_object.extractall('./')
zip_object.close
# Out:
# <bound method ZipFile.close of <zipfile.ZipFile filename='/content/gdrive/MyDrive/Colab Notebooks/Implementing Artificial Intelligence for Emotion Detection/Projeto 1/files.zip' mode='r'>>

# %%
image = cv2.imread('/content/gdrive/MyDrive/Colab Notebooks/Implementing Artificial Intelligence for Emotion Detection/Projeto 1/download.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=482x610>

# %%
image.shape
# Out:
# (610, 482, 3)

# %% [markdown]
# ## Testando o Detector

# %%
cascade_faces = "Material/haarcascade_frontalface_default.xml"
model_path = "Material/modelo_01_expressoes.h5"
face_detection = cv2.CascadeClassifier(cascade_faces)
emotions_classifier = load_model(model_path, compile = False)
expressions = ["Anger", "Disgust", "Fear", "Happy", "Sad", "Surprised", "Neutral"]

# %% [markdown]
# ## Face detection

# %%
original = image.copy()
faces = face_detection.detectMultiScale(original, scaleFactor = 1.1,
                                        minNeighbors = 3, minSize = (20,20))

# %%
faces
# Out:
# array([[136,  76, 208, 208]], dtype=int32)

# %%
len(faces)
# Out:
# 1

# %%
faces.shape
# Out:
# (1, 4)

# %% [markdown]
# Extração de ROI (region of interest)

# %%
gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=482x610>

# %%
gray.shape
# Out:
# (610, 482)

# %%
roi = gray

# %%
roi = gray[40:40 + 230, 162:162 + 140]
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=L size=140x230>

# %%
roi.shape
# Out:
# (230, 140)

# %%
roi
# Out:
# array([[206, 204, 199, ..., 205, 203, 194],
#        [206, 207, 202, ..., 187, 204, 199],
#        [207, 208, 199, ..., 183, 196, 209],
#        ...,
#        [103,  82, 109, ..., 105,  98,  54],
#        [102,  83, 129, ...,  96,  38,  37],
#        [ 99,  81,  82, ...,  43,  35,  35]], dtype=uint8)

# %%
roi = cv2.resize(roi, (48, 48))
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=L size=48x48>

# %%
roi.dtype
# Out:
# dtype('uint8')

# %%
roi = roi.astype('float')
roi.dtype
# Out:
# dtype('float64')

# %%
roi
# Out:
# array([[208., 204., 207., ..., 208., 201., 197.],
#        [203., 206., 209., ...,  79., 168., 188.],
#        [203., 204., 203., ...,  98.,  75.,  95.],
#        ...,
#        [ 85.,  49.,  30., ..., 181., 167., 155.],
#        [ 85.,  57.,  31., ..., 170., 162., 136.],
#        [ 83.,  78.,  69., ..., 159., 128.,  90.]])

# %%
roi = roi / 255
roi
# Out:
# array([[0.81568627, 0.8       , 0.81176471, ..., 0.81568627, 0.78823529,
#         0.77254902],
#        [0.79607843, 0.80784314, 0.81960784, ..., 0.30980392, 0.65882353,
#         0.7372549 ],
#        [0.79607843, 0.8       , 0.79607843, ..., 0.38431373, 0.29411765,
#         0.37254902],
#        ...,
#        [0.33333333, 0.19215686, 0.11764706, ..., 0.70980392, 0.65490196,
#         0.60784314],
#        [0.33333333, 0.22352941, 0.12156863, ..., 0.66666667, 0.63529412,
#         0.53333333],
#        [0.3254902 , 0.30588235, 0.27058824, ..., 0.62352941, 0.50196078,
#         0.35294118]])

# %%
roi = img_to_array(roi)
roi
# Out:
# array([[[0.8156863 ],
#         [0.8       ],
#         [0.8117647 ],
#         ...,
#         [0.8156863 ],
#         [0.7882353 ],
#         [0.77254903]],
#
#        [[0.79607844],
#         [0.80784315],
#         [0.81960785],
#         ...,
#         [0.30980393],
#         [0.65882355],
#         [0.7372549 ]],
#
#        [[0.79607844],
#         [0.8       ],
#         [0.79607844],
#         ...,
#         [0.38431373],
#         [0.29411766],
#         [0.37254903]],
#
#        ...,
#
#        [[0.33333334],
#         [0.19215687],
#         [0.11764706],
#         ...,
#         [0.70980394],
#         [0.654902  ],
#         [0.60784316]],
#
#        [[0.33333334],
#         [0.22352941],
#         [0.12156863],
#         ...,
#         [0.6666667 ],
#         [0.63529414],
#         [0.53333336]],
#
#        [[0.3254902 ],
#         [0.30588236],
#         [0.27058825],
#         ...,
#         [0.62352943],
#         [0.5019608 ],
# ...

# %%
roi.shape
# Out:
# (48, 48, 1)

# %%
roi = np.expand_dims(roi, axis = 0)
roi.shape
# Out:
# (1, 48, 48, 1)

# %% [markdown]
# ## Previsões

# %%
preds = emotions_classifier.predict(roi)[0]
# Out:
# 1/1 [==============================] - 1s 540ms/step

# %%
preds
# Out:
# array([6.4363673e-13, 2.1368869e-22, 5.1944872e-12, 1.0000000e+00,
#        4.0683497e-13, 4.0267256e-12, 2.2693219e-11], dtype=float32)

# %%
len(preds)
# Out:
# 7

# %%
emotion_probability = np.max(preds)
emotion_probability
# Out:
# 1.0

# %%
preds.argmax()
# Out:
# 3

# %%
label = expressions[preds.argmax()]
label
# Out:
# 'Happy'

# %% [markdown]
# ## Resultado

# %%
cv2.putText(original, label, (162, 40 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.65,
            (0, 0, 255), 2, cv2.LINE_AA)
cv2.rectangle(original, (162, 40), (162 + 128, 40 + 128), (0, 0, 255), 2)
cv2_imshow(original)
# Out:
# <PIL.Image.Image image mode=RGB size=482x610>

# %%
probability = np.ones((250,300,3), dtype= 'uint8') * 255
probability
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
probability.shape
# Out:
# (250, 300, 3)

# %%
cv2_imshow(original)
if len(faces) == 1:
  for (i, (emotion, prob)) in enumerate(zip(expressions, preds)):
    #print(i, emotion, prob)
    text = "{}: {:.2f}%".format(emotion, prob * 100)
    w = int(prob * 300)
    cv2.rectangle(probability, (7, (i * 35) + 5), (w, (i * 35) + 35), (200, 250, 20), -1)
    cv2.putText(probability, text, (10, (i * 35) + 23), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 0), 1, cv2.LINE_AA)
cv2_imshow(probability)
# Out:
# <PIL.Image.Image image mode=RGB size=482x610>
# <PIL.Image.Image image mode=RGB size=300x250>
